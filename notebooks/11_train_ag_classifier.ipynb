# %%
import pandas as pd 
from autogluon.tabular import TabularPredictor

from superpac. base import get_split_mmp_indices

# %% [markdown]
# ### Load and split data

# %%
full_df = pd.read_csv('./MACCS_keys/MACCS_encoding.csv')

ds_size = len(full_df)
zero_out, one_out, two_out = get_split_mmp_indices("./index sets for train test split", ds_size)

zero_out_df = full_df.iloc[zero_out]
two_out_df = full_df.iloc[two_out]
one_out_df = full_df.iloc[one_out]

train_data = zero_out_df.drop('pKi_diff', axis=1)
test_data = two_out_df.drop('pKi_diff', axis=1)
one_data = one_out_df.drop('pKi_diff', axis=1)

label = 'is_AC'


y_train = train_data[label]
y_test = test_data[label]
y_one = one_data[label]

X_train = pd.DataFrame(train_data.drop(columns=[label]))
X_test = pd.DataFrame(test_data.drop(columns=[label]))
X_one = pd.DataFrame(one_data.drop(columns=[label]))

# %% [markdown]
# ## Training classifiers
#
# AutoGluon TabularPredictor will train NeuralNets, Random Forests, ExtraTrees, CatBoost models and their multi-layer stacked ensembles.

# %%
save_path = 'agClassifier'
metric = 'roc_auc'
time_limit = 12000


predictor = TabularPredictor(label, eval_metric=metric, path=save_path)
predictor.fit(train_data, time_limit=time_limit, presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 12000s
# AutoGluon will save models to "agModel_class_frag/"
# AutoGluon Version:  0.4.0
# Python Version:     3.8.3
# Operating System:   Darwin
# Train Data Rows:    7089
# Train Data Columns: 498
# Label Column: is_AC
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    1567.4 MB
# 	Train Data (Original)  Memory Usage: 28.24 MB (1.8% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 432 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Useless Original Features (Count: 66): ['core_1', 'F1_1', 'F2_1', 'core_2', 'F1_2', 'F2_2', 'core_3', 'F1_3', 'F2_3', 'core_4', 'F2_4', 'F1_5', 'F2_5', 'core_6', 'F2_6', 'F1_7', 'F2_7', 'F1_9', 'F1_10', 'core_12', 'F1_12', 'F1_15', 'core_55', 'F2_55', 'F1_56', 'F2_56', 'core_57', 'F1_57', 'F2_57', 'core_58', 'F1_58', 'core_59', 'F1_59', 'core_60', 'F2_60', 'core_61', 'F1_61', 'F2_62', 'core_63', 'F2_64', 'F2_67', 'core_69', 'F2_70', 'F2_72', 'F1_111', 'F2_111', 'core_112', 'F1_112', 'F2_112', 'core_113', 'F1_113', 'F2_113', 'F1_114', 'F2_114', 'F1_115', 'core_116', 'F1_116', 'F2_116', 'core_118', 'F1_118', 'core_120', 'core_123', 'F1_124', 'core_126', 'F1_126', 'F2_166']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', []) : 432 | ['F1_4', 'core_5', 'F1_6', 'core_7', 'core_8', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('int', ['bool']) : 432 | ['F1_4', 'core_5', 'F1_6', 'core_7', 'core_8', ...]
# 	9.8s = Fit runtime
# 	432 features in original data used to generate 432 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.06 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 10.13s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 7991.25s of the 11989.87s of remaining time.
# 	No valid features to train KNeighborsUnif_BAG_L1... Skipping this model.
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 7991.2s of the 11989.82s of remaining time.
# 	No valid features to train KNeighborsDist_BAG_L1... Skipping this model.
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 7991.17s of the 11989.78s of remaining time.
# 	Will use sequential fold fitting strategy because Darwin OS does not yet support parallel folding.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 7986.91s of the 11985.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 7985.91s of the 11984.52s of remaining time.
# 	0.9287	 = Validation score   (roc_auc)
# 	5.55s	 = Training   runtime
# 	5.9s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 7973.73s of the 11972.35s of remaining time.
# 	0.9302	 = Validation score   (roc_auc)
# 	6.46s	 = Training   runtime
# 	4.49s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 7962.35s of the 11960.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.928	 = Validation score   (roc_auc)
# 	201.54s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 7760.39s of the 11759.01s of remaining time.
# 	0.9303	 = Validation score   (roc_auc)
# 	4.62s	 = Training   runtime
# 	5.13s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 7750.4s of the 11749.02s of remaining time.
# 	0.929	 = Validation score   (roc_auc)
# 	3.98s	 = Training   runtime
# 	2.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 7743.48s of the 11742.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# 	0.8946	 = Validation score   (roc_auc)
# 	144.59s	 = Training   runtime
# 	2.71s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 7595.26s of the 11593.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused XGBoost_BAG_L1 to fail during training... Skipping this model.
# 		XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ['dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1074, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1032, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 577, in fit
#     out = self._fit(**kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 153, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 211, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 481, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 217, in after_all_folds_scheduled
#     self._fit_fold_model(job)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 222, in _fit_fold_model
#     fold_model = self._fit(self.model_base, time_start_fold, time_limit_fold, fold_ctx, self.model_base_kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 252, in _fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **kwargs_fold)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 577, in fit
#     out = self._fit(**kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 121, in _fit
#     try_import_xgboost()
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/utils/try_import.py", line 104, in try_import_xgboost
#     import xgboost
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/__init__.py", line 9, in <module>
#     from .core import DMatrix, DeviceQuantileDMatrix, Booster
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 195, in <module>
#     _LIB = _load_lib()
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 178, in _load_lib
#     raise XGBoostError(
# xgboost.core.XGBoostError: XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ['dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']
#
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 7594.86s of the 11593.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9121	 = Validation score   (roc_auc)
# 	259.45s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 7334.67s of the 11333.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Repeating k-fold bagging: 2/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 7334.38s of the 11333.0s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9319	 = Validation score   (roc_auc)
# 	386.49s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 7148.98s of the 11147.59s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 8: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# 	0.9071	 = Validation score   (roc_auc)
# 	273.17s	 = Training   runtime
# 	3.9s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 7018.97s of the 11017.59s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9219	 = Validation score   (roc_auc)
# 	453.55s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 6824.63s of the 10823.25s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9337	 = Validation score   (roc_auc)
# 	558.14s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 6651.65s of the 10650.27s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# 	0.9122	 = Validation score   (roc_auc)
# 	391.96s	 = Training   runtime
# 	5.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 6531.28s of the 10529.9s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9237	 = Validation score   (roc_auc)
# 	648.6s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 6335.91s of the 10334.52s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9338	 = Validation score   (roc_auc)
# 	754.23s	 = Training   runtime
# 	2.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 6139.23s of the 10137.84s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# 	0.9145	 = Validation score   (roc_auc)
# 	526.4s	 = Training   runtime
# 	6.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 6003.29s of the 10001.91s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9255	 = Validation score   (roc_auc)
# 	885.23s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 5766.25s of the 9764.86s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.934	 = Validation score   (roc_auc)
# 	961.61s	 = Training   runtime
# 	2.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 5558.28s of the 9556.89s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 8: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 9: early stopping
# 	0.9159	 = Validation score   (roc_auc)
# 	655.51s	 = Training   runtime
# 	7.8s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 5427.4s of the 9426.01s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9275	 = Validation score   (roc_auc)
# 	1092.55s	 = Training   runtime
# 	0.77s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 5219.85s of the 9218.46s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9344	 = Validation score   (roc_auc)
# 	1130.78s	 = Training   runtime
# 	2.63s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 5050.3s of the 9048.92s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# 	0.9191	 = Validation score   (roc_auc)
# 	771.88s	 = Training   runtime
# 	9.26s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 4932.2s of the 8930.81s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9283	 = Validation score   (roc_auc)
# 	1325.02s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 4699.47s of the 8698.09s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9341	 = Validation score   (roc_auc)
# 	1283.55s	 = Training   runtime
# 	2.85s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 4546.32s of the 8544.94s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 8: early stopping
# 	0.9206	 = Validation score   (roc_auc)
# 	881.61s	 = Training   runtime
# 	10.68s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 4434.91s of the 8433.53s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9294	 = Validation score   (roc_auc)
# 	1503.66s	 = Training   runtime
# 	1.02s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 4255.99s of the 8254.6s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9343	 = Validation score   (roc_auc)
# 	1441.37s	 = Training   runtime
# 	3.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 4097.81s of the 8096.42s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 8: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 8: early stopping
# 	0.9209	 = Validation score   (roc_auc)
# 	971.6s	 = Training   runtime
# 	11.58s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 4006.71s of the 8005.33s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9296	 = Validation score   (roc_auc)
# 	1690.99s	 = Training   runtime
# 	1.12s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3819.19s of the 7817.81s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9343	 = Validation score   (roc_auc)
# 	1602.86s	 = Training   runtime
# 	3.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3657.31s of the 7655.93s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# 	0.9208	 = Validation score   (roc_auc)
# 	1073.53s	 = Training   runtime
# 	12.7s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3553.99s of the 7552.61s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9301	 = Validation score   (roc_auc)
# 	1880.12s	 = Training   runtime
# 	1.27s	 = Validation runtime
# Repeating k-fold bagging: 10/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3364.6s of the 7363.22s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9342	 = Validation score   (roc_auc)
# 	1730.31s	 = Training   runtime
# 	3.51s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3236.87s of the 7235.48s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 9: early stopping
# 	0.9204	 = Validation score   (roc_auc)
# 	1174.21s	 = Training   runtime
# 	13.63s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3135.04s of the 7133.66s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9319	 = Validation score   (roc_auc)
# 	2058.29s	 = Training   runtime
# 	1.38s	 = Validation runtime
# Repeating k-fold bagging: 11/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2956.64s of the 6955.25s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9343	 = Validation score   (roc_auc)
# 	1858.48s	 = Training   runtime
# 	3.7s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2828.18s of the 6826.8s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# 	0.92	 = Validation score   (roc_auc)
# 	1265.29s	 = Training   runtime
# 	14.54s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2735.98s of the 6734.59s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9316	 = Validation score   (roc_auc)
# 	2213.11s	 = Training   runtime
# 	1.48s	 = Validation runtime
# Repeating k-fold bagging: 12/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2580.96s of the 6579.58s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9344	 = Validation score   (roc_auc)
# 	1994.36s	 = Training   runtime
# 	3.93s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2444.74s of the 6443.36s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# 	0.9208	 = Validation score   (roc_auc)
# 	1356.93s	 = Training   runtime
# 	15.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2351.97s of the 6350.59s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9321	 = Validation score   (roc_auc)
# 	2416.49s	 = Training   runtime
# 	1.65s	 = Validation runtime
# Repeating k-fold bagging: 13/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2148.31s of the 6146.92s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9344	 = Validation score   (roc_auc)
# 	2150.25s	 = Training   runtime
# 	4.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1992.06s of the 5990.68s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 6: early stopping
# 	0.9219	 = Validation score   (roc_auc)
# 	1452.7s	 = Training   runtime
# 	16.73s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1894.77s of the 5893.39s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9324	 = Validation score   (roc_auc)
# 	2581.39s	 = Training   runtime
# 	1.78s	 = Validation runtime
# Repeating k-fold bagging: 14/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1729.58s of the 5728.19s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9346	 = Validation score   (roc_auc)
# 	2303.61s	 = Training   runtime
# 	4.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1575.8s of the 5574.42s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# 	0.9224	 = Validation score   (roc_auc)
# 	1551.08s	 = Training   runtime
# 	17.73s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1476.16s of the 5474.78s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9323	 = Validation score   (roc_auc)
# 	2762.53s	 = Training   runtime
# 	1.89s	 = Validation runtime
# Repeating k-fold bagging: 15/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1294.77s of the 5293.39s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9344	 = Validation score   (roc_auc)
# 	2435.52s	 = Training   runtime
# 	4.62s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1162.48s of the 5161.09s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 6: early stopping
# 	0.9221	 = Validation score   (roc_auc)
# 	1668.63s	 = Training   runtime
# 	18.93s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1043.43s of the 5042.04s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9325	 = Validation score   (roc_auc)
# 	3009.39s	 = Training   runtime
# 	2.05s	 = Validation runtime
# Repeating k-fold bagging: 16/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 796.22s of the 4794.84s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9344	 = Validation score   (roc_auc)
# 	2575.15s	 = Training   runtime
# 	4.81s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 656.29s of the 4654.9s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 4: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 6: early stopping
# 	0.9225	 = Validation score   (roc_auc)
# 	1757.39s	 = Training   runtime
# 	19.85s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 566.39s of the 4565.01s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9329	 = Validation score   (roc_auc)
# 	3203.07s	 = Training   runtime
# 	2.17s	 = Validation runtime
# Completed 16/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 799.12s of the 4371.0s of remaining time.
# 	0.9405	 = Validation score   (roc_auc)
# 	3.67s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 11 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 4367.29s of the 4367.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMXT_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 4366.77s of the 4366.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBM_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 4365.85s of the 4365.75s of remaining time.
# 	0.9397	 = Validation score   (roc_auc)
# 	3.37s	 = Training   runtime
# 	1.84s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 4360.19s of the 4360.14s of remaining time.
# 	0.9428	 = Validation score   (roc_auc)
# 	3.11s	 = Training   runtime
# 	1.98s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 4354.92s of the 4354.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9417	 = Validation score   (roc_auc)
# 	69.68s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 4284.7s of the 4284.66s of remaining time.
# 	0.9429	 = Validation score   (roc_auc)
# 	3.28s	 = Training   runtime
# 	2.93s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 4278.26s of the 4278.22s of remaining time.
# 	0.9442	 = Validation score   (roc_auc)
# 	3.22s	 = Training   runtime
# 	2.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 4272.74s of the 4272.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# 	0.9071	 = Validation score   (roc_auc)
# 	88.17s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 4183.08s of the 4183.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused XGBoost_BAG_L2 to fail during training... Skipping this model.
# 		XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ['dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1074, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1032, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 577, in fit
#     out = self._fit(**kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 153, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 211, in _fit
#     self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 481, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 217, in after_all_folds_scheduled
#     self._fit_fold_model(job)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 222, in _fit_fold_model
#     fold_model = self._fit(self.model_base, time_start_fold, time_limit_fold, fold_ctx, self.model_base_kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 252, in _fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **kwargs_fold)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 577, in fit
#     out = self._fit(**kwargs)
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 121, in _fit
#     try_import_xgboost()
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/autogluon/core/utils/try_import.py", line 104, in try_import_xgboost
#     import xgboost
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/__init__.py", line 9, in <module>
#     from .core import DMatrix, DeviceQuantileDMatrix, Booster
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 195, in <module>
#     _LIB = _load_lib()
#   File "/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 178, in _load_lib
#     raise XGBoostError(
# xgboost.core.XGBoostError: XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ['dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']
#
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 4182.7s of the 4182.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9335	 = Validation score   (roc_auc)
# 	86.63s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 4095.74s of the 4095.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMLarge_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/ericlasry/opt/anaconda3/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Repeating k-fold bagging: 2/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 4095.53s of the 4095.5s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9419	 = Validation score   (roc_auc)
# 	138.33s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 4026.63s of the 4026.59s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 8: early stopping
# 	0.9184	 = Validation score   (roc_auc)
# 	178.02s	 = Training   runtime
# 	2.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 3935.44s of the 3935.4s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9361	 = Validation score   (roc_auc)
# 	173.55s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 3848.03s of the 3847.96s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9424	 = Validation score   (roc_auc)
# 	210.57s	 = Training   runtime
# 	0.92s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 3775.33s of the 3775.29s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# 	0.9202	 = Validation score   (roc_auc)
# 	265.66s	 = Training   runtime
# 	3.29s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 3686.5s of the 3686.46s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9368	 = Validation score   (roc_auc)
# 	266.89s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 3592.62s of the 3592.52s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9425	 = Validation score   (roc_auc)
# 	308.54s	 = Training   runtime
# 	1.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 3494.14s of the 3494.1s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 4: early stopping
# 	0.9233	 = Validation score   (roc_auc)
# 	384.89s	 = Training   runtime
# 	4.42s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 3373.54s of the 3373.5s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9374	 = Validation score   (roc_auc)
# 	362.52s	 = Training   runtime
# 	1.0s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 3277.61s of the 3277.57s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9427	 = Validation score   (roc_auc)
# 	384.57s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 3201.28s of the 3201.24s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# 	0.9247	 = Validation score   (roc_auc)
# 	496.01s	 = Training   runtime
# 	5.73s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 3088.53s of the 3088.47s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9376	 = Validation score   (roc_auc)
# 	459.43s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 2991.27s of the 2991.23s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9429	 = Validation score   (roc_auc)
# 	453.23s	 = Training   runtime
# 	1.59s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 2922.35s of the 2922.31s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# 	0.9253	 = Validation score   (roc_auc)
# 	593.45s	 = Training   runtime
# 	7.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2823.39s of the 2823.35s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9377	 = Validation score   (roc_auc)
# 	545.59s	 = Training   runtime
# 	1.34s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 2736.95s of the 2736.91s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9427	 = Validation score   (roc_auc)
# 	512.79s	 = Training   runtime
# 	1.77s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 2677.12s of the 2677.08s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 4: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 4: early stopping
# 	0.925	 = Validation score   (roc_auc)
# 	687.35s	 = Training   runtime
# 	8.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2581.96s of the 2581.92s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.938	 = Validation score   (roc_auc)
# 	638.29s	 = Training   runtime
# 	1.53s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 2488.95s of the 2488.91s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9427	 = Validation score   (roc_auc)
# 	574.52s	 = Training   runtime
# 	1.96s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 2426.96s of the 2426.92s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 6: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# 	0.9258	 = Validation score   (roc_auc)
# 	779.56s	 = Training   runtime
# 	9.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2333.38s of the 2333.34s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.938	 = Validation score   (roc_auc)
# 	726.57s	 = Training   runtime
# 	1.7s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 2244.81s of the 2244.77s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9427	 = Validation score   (roc_auc)
# 	648.58s	 = Training   runtime
# 	2.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 2170.48s of the 2170.44s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 6: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# 	0.9256	 = Validation score   (roc_auc)
# 	873.95s	 = Training   runtime
# 	10.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2074.86s of the 2074.82s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9381	 = Validation score   (roc_auc)
# 	816.93s	 = Training   runtime
# 	1.88s	 = Validation runtime
# Repeating k-fold bagging: 10/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1984.21s of the 1984.17s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9427	 = Validation score   (roc_auc)
# 	723.24s	 = Training   runtime
# 	2.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1909.26s of the 1909.23s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# 	0.9252	 = Validation score   (roc_auc)
# 	975.17s	 = Training   runtime
# 	11.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1806.72s of the 1806.68s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.938	 = Validation score   (roc_auc)
# 	910.38s	 = Training   runtime
# 	2.05s	 = Validation runtime
# Repeating k-fold bagging: 11/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1712.98s of the 1712.94s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9428	 = Validation score   (roc_auc)
# 	810.46s	 = Training   runtime
# 	2.53s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1625.36s of the 1625.31s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 7: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 5: early stopping
# 	0.9255	 = Validation score   (roc_auc)
# 	1094.53s	 = Training   runtime
# 	12.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1504.7s of the 1504.67s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9381	 = Validation score   (roc_auc)
# 	1052.46s	 = Training   runtime
# 	2.26s	 = Validation runtime
# Repeating k-fold bagging: 12/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1362.27s of the 1362.23s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9429	 = Validation score   (roc_auc)
# 	916.1s	 = Training   runtime
# 	2.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1256.33s of the 1256.29s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 6: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 7: early stopping
# 	0.9253	 = Validation score   (roc_auc)
# 	1214.97s	 = Training   runtime
# 	13.26s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1134.63s of the 1134.59s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.938	 = Validation score   (roc_auc)
# 	1186.37s	 = Training   runtime
# 	2.46s	 = Validation runtime
# Repeating k-fold bagging: 13/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1000.37s of the 1000.33s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9429	 = Validation score   (roc_auc)
# 	1003.03s	 = Training   runtime
# 	2.9s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 913.14s of the 913.11s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 4: early stopping
# No improvement since epoch 3: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# 	0.9256	 = Validation score   (roc_auc)
# 	1328.12s	 = Training   runtime
# 	14.22s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 798.78s of the 798.74s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.938	 = Validation score   (roc_auc)
# 	1300.02s	 = Training   runtime
# 	2.63s	 = Validation runtime
# Repeating k-fold bagging: 14/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 684.76s of the 684.71s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9429	 = Validation score   (roc_auc)
# 	1088.2s	 = Training   runtime
# 	3.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 599.3s of the 599.26s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 5: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 9: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 5: early stopping
# No improvement since epoch 4: early stopping
# 	0.9258	 = Validation score   (roc_auc)
# 	1435.87s	 = Training   runtime
# 	15.18s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 490.34s of the 490.3s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.9381	 = Validation score   (roc_auc)
# 	1408.33s	 = Training   runtime
# 	2.8s	 = Validation runtime
# Completed 14/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 436.73s of the 381.65s of remaining time.
# 	0.9467	 = Validation score   (roc_auc)
# 	5.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 11623.87s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModel_class_frag/")
#                       model  score_test  score_val  pred_time_test  \
# 0       WeightedEnsemble_L3    0.804382   0.946709       31.079878
# 1     ExtraTreesGini_BAG_L1    0.804141   0.930281        0.144838
# 2   RandomForestGini_BAG_L1    0.804091   0.928731        0.145879
# 3           CatBoost_BAG_L2    0.803800   0.942899       30.660631
# 4   RandomForestGini_BAG_L2    0.802915   0.939651       28.722749
# 5     ExtraTreesGini_BAG_L2    0.802626   0.942870       28.733588
# 6   RandomForestEntr_BAG_L1    0.802501   0.930208        0.152590
# 7     ExtraTreesEntr_BAG_L2    0.800814   0.944164       28.732929
# 8     ExtraTreesEntr_BAG_L1    0.800761   0.928983        0.196180
# 9   RandomForestEntr_BAG_L2    0.799363   0.942796       28.723475
# 10      WeightedEnsemble_L2    0.799248   0.940550       28.256875
# 11    NeuralNetTorch_BAG_L2    0.795317   0.938081       33.273992
# 12          CatBoost_BAG_L1    0.789313   0.934421        2.183680
# 13   NeuralNetFastAI_BAG_L2    0.783376   0.925755       46.174785
# 14    NeuralNetTorch_BAG_L1    0.781050   0.932932        3.907540
# 15   NeuralNetFastAI_BAG_L1    0.779396   0.922522       21.861098
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 0       55.180279  8659.492607                 0.004669
# 1        5.134617     4.620638                 0.144838
# 2        5.900046     5.553252                 0.145879
# 3       48.156436  8644.423369                 2.068826
# 4       46.911212  7559.592459                 0.130944
# 5       47.998880  7559.495111                 0.141783
# 6        4.488874     6.457156                 0.152590
# 7       47.189766  7559.440233                 0.141124
# 8        2.722427     3.976683                 0.196180
# 9       47.050279  7559.327210                 0.131670
# 10      36.452756  7550.360494                 0.007129
# 11      47.875349  8964.553640                 4.682187
# 12       4.813488  2575.145343                 2.183680
# 13      60.249035  8992.092965                17.582980
# 14       2.168111  3203.071987                 3.907540
# 15      19.845030  1757.394527                21.861098
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.002698           5.465445            3       True
# 1                 5.134617           4.620638            1       True
# 2                 5.900046           5.553252            1       True
# 3                 3.083843        1088.203782            2       True
# 4                 1.838619           3.372872            2       True
# 5                 2.926286           3.275524            2       True
# 6                 4.488874           6.457156            1       True
# 7                 2.117173           3.220646            2       True
# 8                 2.722427           3.976683            1       True
# 9                 1.977686           3.107623            2       True
# 10                0.002635           3.670842            2       True
# 11                2.802755        1408.334053            2       True
# 12                4.813488        2575.145343            1       True
# 13               15.176442        1435.873378            2       True
# 14                2.168111        3203.071987            1       True
# 15               19.845030        1757.394527            1       True
#
#     fit_order
# 0          16
# 1           4
# 2           1
# 3          11
# 4           9
# 5          12
# 6           2
# 7          13
# 8           5
# 9          10
# 10          8
# 11         15
# 12          3
# 13         14
# 14          7
# 15          6

# %% [markdown]
# ### Pruning the predictor of unwanted models:

# %%
predictor = TabularPredictor.load("./agModel_class_frag")
predictor.delete_models(models_to_keep=["CatBoost_BAG_L1", "CatBoost_BAG_L2", "ExtraTreesGini_BAG_L1", "ExtraTreesEntr_BAG_L1", "ExtraTreesGini_BAG_L2", "ExtraTreesEntr_BAG_L2",
    "RandomForestEntr_BAG_L1", "RandomForestGini_BAG_L1","RandomForestEntr_BAG_L2","RandomForestGini_BAG_L2"], dry_run=False)
# Out:
# Deleting model WeightedEnsemble_L2. All files under ./agModel_class_frag/models/WeightedEnsemble_L2/ will be removed.
# Deleting model NeuralNetFastAI_BAG_L2. All files under ./agModel_class_frag/models/NeuralNetFastAI_BAG_L2/ will be removed.
# Deleting model NeuralNetTorch_BAG_L2. All files under ./agModel_class_frag/models/NeuralNetTorch_BAG_L2/ will be removed.
# Deleting model WeightedEnsemble_L3. All files under ./agModel_class_frag/models/WeightedEnsemble_L3/ will be removed.

# %%
results = predictor.fit_summary(show_plot = True)
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0     ExtraTreesEntr_BAG_L2   0.944164      47.189766  7559.440233                2.117173           3.220646            2       True         12
# 1           CatBoost_BAG_L2   0.942899      48.156436  8644.423369                3.083843        1088.203782            2       True         10
# 2     ExtraTreesGini_BAG_L2   0.942870      47.998880  7559.495111                2.926286           3.275524            2       True         11
# 3   RandomForestEntr_BAG_L2   0.942796      47.050279  7559.327210                1.977686           3.107623            2       True          9
# 4   RandomForestGini_BAG_L2   0.939651      46.911212  7559.592459                1.838619           3.372872            2       True          8
# 5           CatBoost_BAG_L1   0.934421       4.813488  2575.145343                4.813488        2575.145343            1       True          3
# 6     NeuralNetTorch_BAG_L1   0.932932       2.168111  3203.071987                2.168111        3203.071987            1       True          7
# 7     ExtraTreesGini_BAG_L1   0.930281       5.134617     4.620638                5.134617           4.620638            1       True          4
# 8   RandomForestEntr_BAG_L1   0.930208       4.488874     6.457156                4.488874           6.457156            1       True          2
# 9     ExtraTreesEntr_BAG_L1   0.928983       2.722427     3.976683                2.722427           3.976683            1       True          5
# 10  RandomForestGini_BAG_L1   0.928731       5.900046     5.553252                5.900046           5.553252            1       True          1
# 11   NeuralNetFastAI_BAG_L1   0.922522      19.845030  1757.394527               19.845030        1757.394527            1       True          6
# Number of models trained: 12
# Types of models trained:
# {'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_XT'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('int', ['bool']) : 432 | ['F1_4', 'core_5', 'F1_6', 'core_7', 'core_8', ...]
# Plot summary of models saved to file: ./agModel_class_frag/SummaryOfModels.html
# *** End of fit() summary ***

# %% [markdown]
# ### Quick evaluation on the test set:

# %%
y_pred = predictor.predict_proba(X_test)


performance = predictor.evaluate_predictions(y_true = y_test, y_pred = y_pred, auxiliary_metrics = True)
# Out:
# Evaluation: roc_auc on test data: 0.7579628137809655
# Evaluations on test data:
# {
#     "roc_auc": 0.7579628137809655,
#     "accuracy": 0.8850509626274066,
#     "balanced_accuracy": 0.6068383949167403,
#     "mcc": 0.2857391549155361,
#     "f1": 0.3255813953488372,
#     "precision": 0.47115384615384615,
#     "recall": 0.24873096446700507
# }
